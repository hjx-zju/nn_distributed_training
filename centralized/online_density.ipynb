# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import glob
import copy
from models.fourier_nn import FourierNet
from floorplans.lidar.lidar import ClippedLidar2D, Lidar2D, RandomPoseLidarDataset, TrajectoryLidarDataset, OnlineTrajectoryLidarDataset

torch.set_default_tensor_type(torch.DoubleTensor)

# %%
data_dir = "../floorplans/32_data"

waypoint_dir = os.path.join(data_dir, "tight_paths")
# waypoint_dir = os.path.join(data_dir, "minimal_overlap")

img_path = os.path.join(data_dir, "floor_img.png")

# Data parameters
num_beams = 20
beam_samps = 25
beam_length = 0.2
spline_res = 30
samp_distribution_factor = 1.0
collision_samps = 50
fine_samps = 3
num_scans_in_window = 500
lidar = Lidar2D(img_path, num_beams, beam_length, beam_samps, 
    samp_distribution_factor, collision_samps, fine_samps,
    border_width=30)
#lidar = ClippedLidar2D(img_path, num_beams, beam_length, beam_samps,
#    border_width=30)

datasets = []
for name in glob.glob1(waypoint_dir, "*.npy"):
    waypoints = np.load(os.path.join(waypoint_dir, name))
    ds = OnlineTrajectoryLidarDataset(lidar, waypoints, 
        spline_res, num_scans_in_window)
    #ds = RandomPoseLidarDataset(lidar, 6000)
    print()
    print(name, " : ", len(ds), " scan points")
    print(name, " : ", (torch.sum(ds.scans[:,2] == 1.0) / ds.scans.shape[0]).data.item(), "hd point ratio")
    datasets.append(ds)

# Concatenate the entire dataset
#cent_ds = torch.utils.data.ConcatDataset(datasets)
num_validation_scans = 500
valset = RandomPoseLidarDataset(lidar, num_validation_scans)
# Out:
# 1.npy  :  1215000  scan points
# 1.npy  :  0.03564197530864197 hd point ratio
#
# 2.npy  :  1215000  scan points
# 2.npy  :  0.029875720164609054 hd point ratio
#
# 4.npy  :  1185000  scan points
# 4.npy  :  0.0322 hd point ratio
#
# 7.npy  :  1215000  scan points
# 7.npy  :  0.028678189300411522 hd point ratio
#
# 3.npy  :  1215000  scan points
# 3.npy  :  0.03481810699588477 hd point ratio
#
# 5.npy  :  1215000  scan points
# 5.npy  :  0.03394814814814815 hd point ratio
#
# 6.npy  :  1215000  scan points
# 6.npy  :  0.030379423868312758 hd point ratio

# %%
if torch.cuda.is_available(): 
    device = torch.device("cuda")
else: 
    device = torch.device("cpu")

# Setup model and centralized optimizer
model = FourierNet([2, 256, 64, 64, 64, 1], scale=0.05).to(device)
opt = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
#batch_size = 10000


loss = torch.nn.BCELoss()
val_loader = torch.utils.data.DataLoader(valset, batch_size=10000)

N = 7
batch_size = 12500
dloaders = []
diters = []
for i in range(N):
    dl = torch.utils.data.DataLoader(datasets[i], batch_size=batch_size)
    dloaders.append(dl)
    diters.append(iter(dl))

epoch_tracker = torch.zeros(N)
current_epoch = 0
epochs = 4
from torch.optim.lr_scheduler import StepLR

# 创建StepLR实例
scheduler = StepLR(opt, step_size=66, gamma=0.5)
v_loss_list=[]
X, Y = np.meshgrid(torch.Tensor(lidar.xs), torch.Tensor(lidar.ys))
xlocs = X[::8, ::8].reshape(-1, 1)
ylocs = Y[::8, ::8].reshape(-1, 1)
xlocs=torch.Tensor(xlocs)
ylocs=torch.Tensor(ylocs)
mesh_inputs = torch.hstack((xlocs, ylocs))
mesh_inputs = mesh_inputs.to(device)
while current_epoch <= 200:
    locs = []
    dens = []
    for i in range(N):
        try:
            batch = next(diters[i])
        except StopIteration:
            epoch_tracker[i] += 1
            diters[i] = iter(dloaders[i])
            batch = next(diters[i])
        locs.append(batch[0].to(device))
        dens.append(batch[1].to(device))
        
    x = torch.cat(locs, axis=0)
    y = torch.cat(dens, axis=0)
        
    opt.zero_grad()
    pd = model.forward(x).squeeze()
    l = loss(pd, y)
    l.backward()
    opt.step()
    if torch.sum(epoch_tracker > current_epoch) >= N:
        current_epoch += 1
        print("-------------------------------")
        print("Epochs: ", epoch_tracker)
        with torch.no_grad():
            vloss = 0.0
            for batch in val_loader:
                x, y = batch[0].to(device), batch[1].to(device)
                pd = model.forward(x).squeeze()
                vloss += loss(pd, y).data
        scheduler.step()
        v_loss_list.append(vloss.item())
        print("Valid loss: ", vloss.item())
    if current_epoch%20==0:
        with torch.no_grad():
            mesh_dense = model.forward(mesh_inputs)
        torch.save(mesh_dense, "mesh/mesh_dense"+str(current_epoch)+".pt")
# torch.save(mesh_dense, "mesh_dense.pt")
# Out:
# -------------------------------
# Epochs:  tensor([1., 1., 1., 1., 1., 1., 1.])
# Valid loss:  5.03585150818252
# -------------------------------
# Epochs:  tensor([2., 2., 2., 2., 2., 2., 2.])
# Valid loss:  4.904688827703425
# -------------------------------
# Epochs:  tensor([3., 3., 3., 3., 3., 3., 3.])
# Valid loss:  4.557630773693396
# -------------------------------
# Epochs:  tensor([4., 4., 4., 4., 4., 4., 4.])
# Valid loss:  4.140294231141497
# -------------------------------
# Epochs:  tensor([5., 5., 5., 5., 5., 5., 5.])
# Valid loss:  4.09478570669935
# -------------------------------
# Epochs:  tensor([6., 6., 6., 6., 6., 6., 6.])
# Valid loss:  3.745570940478039
# -------------------------------
# Epochs:  tensor([7., 7., 7., 7., 7., 7., 7.])
# Valid loss:  3.4214270702913265
# -------------------------------
# Epochs:  tensor([8., 8., 8., 8., 8., 8., 8.])
# Valid loss:  3.2202290735964314
# -------------------------------
# Epochs:  tensor([9., 9., 9., 9., 9., 9., 9.])
# Valid loss:  2.954590319823685
# -------------------------------
# Epochs:  tensor([10., 10., 10., 10., 10., 10., 10.])
# Valid loss:  2.7968391902840977
# -------------------------------
# Epochs:  tensor([11., 11., 11., 11., 11., 11., 11.])
# Valid loss:  2.621323150599947
# -------------------------------
# Epochs:  tensor([12., 12., 12., 12., 12., 12., 12.])
# Valid loss:  2.627158625021231
# -------------------------------
# Epochs:  tensor([13., 13., 13., 13., 13., 13., 13.])
# Valid loss:  2.349064438130308
# -------------------------------
# Epochs:  tensor([14., 14., 14., 14., 14., 14., 14.])
# Valid loss:  2.3135019805895953
# -------------------------------
# Epochs:  tensor([15., 15., 15., 15., 15., 15., 15.])
# Valid loss:  2.40497215413788
# -------------------------------
# Epochs:  tensor([16., 16., 16., 16., 16., 16., 16.])
# Valid loss:  2.166550407399752
# -------------------------------
# Epochs:  tensor([17., 17., 17., 17., 17., 17., 17.])
# Valid loss:  2.0712479886826984
# -------------------------------
# Epochs:  tensor([18., 18., 18., 18., 18., 18., 18.])
# Valid loss:  2.0424497451521226
# -------------------------------
# Epochs:  tensor([19., 19., 19., 19., 19., 19., 19.])
# Valid loss:  2.0649471784822633
# -------------------------------
# Epochs:  tensor([20., 20., 20., 20., 20., 20., 20.])
# Valid loss:  2.130314084658813
# -------------------------------
# Epochs:  tensor([21., 21., 21., 21., 21., 21., 21.])
# Valid loss:  1.9658635658083943
# -------------------------------
# Epochs:  tensor([22., 22., 22., 22., 22., 22., 22.])
# Valid loss:  2.049316881063487
# -------------------------------
# Epochs:  tensor([23., 23., 23., 23., 23., 23., 23.])
# Valid loss:  1.978656588109286
# -------------------------------
# Epochs:  tensor([24., 24., 24., 24., 24., 24., 24.])
# Valid loss:  1.9182336154290789
# -------------------------------
# Epochs:  tensor([25., 25., 25., 25., 25., 25., 25.])
# Valid loss:  1.803475499732644
# -------------------------------
# Epochs:  tensor([26., 26., 26., 26., 26., 26., 26.])
# Valid loss:  2.1701686491105048
# -------------------------------
# Epochs:  tensor([27., 27., 27., 27., 27., 27., 27.])
# Valid loss:  1.6945242796047622
# -------------------------------
# Epochs:  tensor([28., 28., 28., 28., 28., 28., 28.])
# Valid loss:  1.8839917055914999
# -------------------------------
# Epochs:  tensor([29., 29., 29., 29., 29., 29., 29.])
# Valid loss:  1.7680411169226975
# -------------------------------
# Epochs:  tensor([30., 30., 30., 30., 30., 30., 30.])
# Valid loss:  2.0581874791595625
# -------------------------------
# Epochs:  tensor([31., 31., 31., 31., 31., 31., 31.])
# Valid loss:  1.6540151746723797
# -------------------------------
# Epochs:  tensor([32., 32., 33., 32., 32., 32., 32.])
# Valid loss:  1.5884856140407322
# -------------------------------
# Epochs:  tensor([33., 33., 34., 33., 33., 33., 33.])
# Valid loss:  1.625268467208985
# -------------------------------
# Epochs:  tensor([34., 34., 35., 34., 34., 34., 34.])
# Valid loss:  1.6516930607054028
# -------------------------------
# Epochs:  tensor([35., 35., 36., 35., 35., 35., 35.])
# Valid loss:  1.7862962720840823
# -------------------------------
# Epochs:  tensor([36., 36., 37., 36., 36., 36., 36.])
# Valid loss:  1.9619533500828181
# -------------------------------
# Epochs:  tensor([37., 37., 38., 37., 37., 37., 37.])
# Valid loss:  1.8743934523676542
# -------------------------------
# Epochs:  tensor([38., 38., 39., 38., 38., 38., 38.])
# Valid loss:  1.5605241404269856
# -------------------------------
# Epochs:  tensor([39., 39., 40., 39., 39., 39., 39.])
# Valid loss:  1.986394581059679
# -------------------------------
# Epochs:  tensor([40., 40., 41., 40., 40., 40., 40.])
# Valid loss:  1.4997810847689488
# -------------------------------
# Epochs:  tensor([41., 41., 42., 41., 41., 41., 41.])
# Valid loss:  1.6277279335859247
# -------------------------------
# Epochs:  tensor([42., 42., 43., 42., 42., 42., 42.])
# Valid loss:  1.506107688961997
# -------------------------------
# Epochs:  tensor([43., 43., 44., 43., 43., 43., 43.])
# Valid loss:  1.5900672596678294
# -------------------------------
# Epochs:  tensor([44., 44., 45., 44., 44., 44., 44.])
# Valid loss:  1.5827490428936635
# -------------------------------
# Epochs:  tensor([45., 45., 46., 45., 45., 45., 45.])
# Valid loss:  1.8605281514949656
# -------------------------------
# Epochs:  tensor([46., 46., 47., 46., 46., 46., 46.])
# Valid loss:  1.5681215157493185
# -------------------------------
# Epochs:  tensor([47., 47., 48., 47., 47., 47., 47.])
# Valid loss:  1.5893767105896381
# -------------------------------
# Epochs:  tensor([48., 48., 49., 48., 48., 48., 48.])
# Valid loss:  1.598074587715642
# -------------------------------
# Epochs:  tensor([49., 49., 50., 49., 49., 49., 49.])
# Valid loss:  1.5311340271290765
# -------------------------------
# Epochs:  tensor([50., 50., 51., 50., 50., 50., 50.])
# Valid loss:  1.382673751234832
# -------------------------------
# Epochs:  tensor([51., 51., 52., 51., 51., 51., 51.])
# Valid loss:  1.493598500395572
# -------------------------------
# Epochs:  tensor([52., 52., 53., 52., 52., 52., 52.])
# Valid loss:  2.0643028285758276
# -------------------------------
# Epochs:  tensor([53., 53., 54., 53., 53., 53., 53.])
# Valid loss:  1.4167253183966628
# -------------------------------
# Epochs:  tensor([54., 54., 55., 54., 54., 54., 54.])
# Valid loss:  2.1086427962401095
# -------------------------------
# Epochs:  tensor([55., 55., 56., 55., 55., 55., 55.])
# Valid loss:  1.4269360572634266
# -------------------------------
# Epochs:  tensor([56., 56., 57., 56., 56., 56., 56.])
# Valid loss:  1.461444238450112
# -------------------------------
# Epochs:  tensor([57., 57., 58., 57., 57., 57., 57.])
# Valid loss:  1.402647816781983
# -------------------------------
# Epochs:  tensor([58., 58., 59., 58., 58., 58., 58.])
# Valid loss:  1.3774198797676425
# -------------------------------
# Epochs:  tensor([59., 59., 60., 59., 59., 59., 59.])
# Valid loss:  1.374468287651695
# -------------------------------
# Epochs:  tensor([60., 60., 61., 60., 60., 60., 60.])
# Valid loss:  1.407351387034486
# -------------------------------
# Epochs:  tensor([61., 61., 62., 61., 61., 61., 61.])
# Valid loss:  1.5264109589793242
# -------------------------------
# Epochs:  tensor([62., 62., 63., 62., 62., 62., 62.])
# Valid loss:  1.334423470946354
# -------------------------------
# Epochs:  tensor([63., 63., 64., 63., 63., 63., 63.])
# Valid loss:  1.4138838556609796
# -------------------------------
# Epochs:  tensor([64., 64., 66., 64., 64., 64., 64.])
# Valid loss:  1.3635982832584328
# -------------------------------
# Epochs:  tensor([65., 65., 67., 65., 65., 65., 65.])
# Valid loss:  1.3159315544361647
# -------------------------------
# Epochs:  tensor([66., 66., 68., 66., 66., 66., 66.])
# Valid loss:  1.6735720579499296
# -------------------------------
# Epochs:  tensor([67., 67., 69., 67., 67., 67., 67.])
# Valid loss:  1.237686887644376
# -------------------------------
# Epochs:  tensor([68., 68., 70., 68., 68., 68., 68.])
# Valid loss:  1.1921565700003436
# -------------------------------
# Epochs:  tensor([69., 69., 71., 69., 69., 69., 69.])
# Valid loss:  1.2150173192927138
# -------------------------------
# Epochs:  tensor([70., 70., 72., 70., 70., 70., 70.])
# Valid loss:  1.2114038210988511
# -------------------------------
# Epochs:  tensor([71., 71., 73., 71., 71., 71., 71.])
# Valid loss:  1.1383584845710266
# -------------------------------
# Epochs:  tensor([72., 72., 74., 72., 72., 72., 72.])
# Valid loss:  1.1877147434083188
# -------------------------------
# Epochs:  tensor([73., 73., 75., 73., 73., 73., 73.])
# Valid loss:  1.2365989048026922
# -------------------------------
# Epochs:  tensor([74., 74., 76., 74., 74., 74., 74.])
# Valid loss:  1.2199734835234366
# -------------------------------
# Epochs:  tensor([75., 75., 77., 75., 75., 75., 75.])
# Valid loss:  1.1751758001900199
# -------------------------------
# Epochs:  tensor([76., 76., 78., 76., 76., 76., 76.])
# Valid loss:  1.316288133213436
# -------------------------------
# Epochs:  tensor([77., 77., 79., 77., 77., 77., 77.])
# Valid loss:  1.2047889527425837
# -------------------------------
# Epochs:  tensor([78., 78., 80., 78., 78., 78., 78.])
# Valid loss:  1.2148536171504456
# -------------------------------
# Epochs:  tensor([79., 79., 81., 79., 79., 79., 79.])
# Valid loss:  1.3253649235198397
# -------------------------------
# Epochs:  tensor([80., 80., 82., 80., 80., 80., 80.])
# Valid loss:  1.1707355332718938
# -------------------------------
# Epochs:  tensor([81., 81., 83., 81., 81., 81., 81.])
# Valid loss:  1.1970301532735108
# -------------------------------
# Epochs:  tensor([82., 82., 84., 82., 82., 82., 82.])
# Valid loss:  1.234110728184759
# -------------------------------
# Epochs:  tensor([83., 83., 85., 83., 83., 83., 83.])
# Valid loss:  1.1910816597659288
# -------------------------------
# Epochs:  tensor([84., 84., 86., 84., 84., 84., 84.])
# Valid loss:  1.1837985084164893
# -------------------------------
# Epochs:  tensor([85., 85., 87., 85., 85., 85., 85.])
# Valid loss:  1.1232471220954483
# -------------------------------
# Epochs:  tensor([86., 86., 88., 86., 86., 86., 86.])
# Valid loss:  1.1513679297707402
# -------------------------------
# Epochs:  tensor([87., 87., 89., 87., 87., 87., 87.])
# Valid loss:  1.1139557636424384
# -------------------------------
# Epochs:  tensor([88., 88., 90., 88., 88., 88., 88.])
# Valid loss:  1.1345088040389888
# -------------------------------
# Epochs:  tensor([89., 89., 91., 89., 89., 89., 89.])
# Valid loss:  1.1391875372825173
# -------------------------------
# Epochs:  tensor([90., 90., 92., 90., 90., 90., 90.])
# Valid loss:  1.1417615911167533
# -------------------------------
# Epochs:  tensor([91., 91., 93., 91., 91., 91., 91.])
# Valid loss:  1.1859062468012636
# -------------------------------
# Epochs:  tensor([92., 92., 94., 92., 92., 92., 92.])
# Valid loss:  1.2671078494755401
# -------------------------------
# Epochs:  tensor([93., 93., 95., 93., 93., 93., 93.])
# Valid loss:  1.1350957280739506
# -------------------------------
# Epochs:  tensor([94., 94., 96., 94., 94., 94., 94.])
# Valid loss:  1.3585529444821456
# -------------------------------
# Epochs:  tensor([95., 95., 98., 95., 95., 95., 95.])
# Valid loss:  1.1732512669365132
# -------------------------------
# Epochs:  tensor([96., 96., 99., 96., 96., 96., 96.])
# Valid loss:  1.1941261339496696
# -------------------------------
# Epochs:  tensor([ 97.,  97., 100.,  97.,  97.,  97.,  97.])
# Valid loss:  1.1698556646294502
# -------------------------------
# Epochs:  tensor([ 98.,  98., 101.,  98.,  98.,  98.,  98.])
# Valid loss:  1.1467124559100879
# -------------------------------
# Epochs:  tensor([ 99.,  99., 102.,  99.,  99.,  99.,  99.])
# Valid loss:  1.2035490833832223
# -------------------------------
# Epochs:  tensor([100., 100., 103., 100., 100., 100., 100.])
# Valid loss:  1.2104122243294557
# -------------------------------
# Epochs:  tensor([101., 101., 104., 101., 101., 101., 101.])
# Valid loss:  1.303870657299589
# -------------------------------
# Epochs:  tensor([102., 102., 105., 102., 102., 102., 102.])
# Valid loss:  1.0443746928357711
# -------------------------------
# Epochs:  tensor([103., 103., 106., 103., 103., 103., 103.])
# Valid loss:  1.1378233575630476
# -------------------------------
# Epochs:  tensor([104., 104., 107., 104., 104., 104., 104.])
# Valid loss:  1.0356912472242725
# -------------------------------
# Epochs:  tensor([105., 105., 108., 105., 105., 105., 105.])
# Valid loss:  1.1393333777187242
# -------------------------------
# Epochs:  tensor([106., 106., 109., 106., 106., 106., 106.])
# Valid loss:  1.051441763398453
# -------------------------------
# Epochs:  tensor([107., 107., 110., 107., 107., 107., 107.])
# Valid loss:  1.237742785113085
# -------------------------------
# Epochs:  tensor([108., 108., 111., 108., 108., 108., 108.])
# Valid loss:  1.2200162473748275
# -------------------------------
# Epochs:  tensor([109., 109., 112., 109., 109., 109., 109.])
# Valid loss:  1.1836078857151102
# -------------------------------
# Epochs:  tensor([110., 110., 113., 110., 110., 110., 110.])
# Valid loss:  1.1207971880787841
# -------------------------------
# Epochs:  tensor([111., 111., 114., 111., 111., 111., 111.])
# Valid loss:  1.1442841857848396
# -------------------------------
# Epochs:  tensor([112., 112., 115., 112., 112., 112., 112.])
# Valid loss:  1.1081876440493712
# -------------------------------
# Epochs:  tensor([113., 113., 116., 113., 113., 113., 113.])
# Valid loss:  1.1765961764400954
# -------------------------------
# Epochs:  tensor([114., 114., 117., 114., 114., 114., 114.])
# Valid loss:  1.1066614746077545
# -------------------------------
# Epochs:  tensor([115., 115., 118., 115., 115., 115., 115.])
# Valid loss:  1.0707072403165052
# -------------------------------
# Epochs:  tensor([116., 116., 119., 116., 116., 116., 116.])
# Valid loss:  1.1973748582619173
# -------------------------------
# Epochs:  tensor([117., 117., 120., 117., 117., 117., 117.])
# Valid loss:  1.1021773104693415
# -------------------------------
# Epochs:  tensor([118., 118., 121., 118., 118., 118., 118.])
# Valid loss:  1.1195749259898646
# -------------------------------
# Epochs:  tensor([119., 119., 122., 119., 119., 119., 119.])
# Valid loss:  1.0261435062562094
# -------------------------------
# Epochs:  tensor([120., 120., 123., 120., 120., 120., 120.])
# Valid loss:  1.103655585606242
# -------------------------------
# Epochs:  tensor([121., 121., 124., 121., 121., 121., 121.])
# Valid loss:  1.0919047616535484
# -------------------------------
# Epochs:  tensor([122., 122., 125., 122., 122., 122., 122.])
# Valid loss:  1.245698512101289
# -------------------------------
# Epochs:  tensor([123., 123., 126., 123., 123., 123., 123.])
# Valid loss:  1.0163228013050478
# -------------------------------
# Epochs:  tensor([124., 124., 127., 124., 124., 124., 124.])
# Valid loss:  1.1026637351396238
# -------------------------------
# Epochs:  tensor([125., 125., 128., 125., 125., 125., 125.])
# Valid loss:  1.0688993946230796
# -------------------------------
# Epochs:  tensor([126., 126., 129., 126., 126., 126., 126.])
# Valid loss:  1.0448011256153231
# -------------------------------
# Epochs:  tensor([127., 127., 131., 127., 127., 127., 127.])
# Valid loss:  1.063573736310898
# -------------------------------
# Epochs:  tensor([128., 128., 132., 128., 128., 128., 128.])
# Valid loss:  1.0732153788324783
# -------------------------------
# Epochs:  tensor([129., 129., 133., 129., 129., 129., 129.])
# Valid loss:  1.0941512958910462
# -------------------------------
# Epochs:  tensor([130., 130., 134., 130., 130., 130., 130.])
# Valid loss:  1.2101013624049954
# -------------------------------
# Epochs:  tensor([131., 131., 135., 131., 131., 131., 131.])
# Valid loss:  1.0475766281619256
# -------------------------------
# Epochs:  tensor([132., 132., 136., 132., 132., 132., 132.])
# Valid loss:  1.1130994687290507
# -------------------------------
# Epochs:  tensor([133., 133., 137., 133., 133., 133., 133.])
# Valid loss:  0.9791722826948496
# -------------------------------
# Epochs:  tensor([134., 134., 138., 134., 134., 134., 134.])
# Valid loss:  0.9139288400784733
# -------------------------------
# Epochs:  tensor([135., 135., 139., 135., 135., 135., 135.])
# Valid loss:  0.9654885416768435
# -------------------------------
# Epochs:  tensor([136., 136., 140., 136., 136., 136., 136.])
# Valid loss:  0.9190847043723294
# -------------------------------
# Epochs:  tensor([137., 137., 141., 137., 137., 137., 137.])
# Valid loss:  0.9412858108215125
# -------------------------------
# Epochs:  tensor([138., 138., 142., 138., 138., 138., 138.])
# Valid loss:  0.9766985770854585
# -------------------------------
# Epochs:  tensor([139., 139., 143., 139., 139., 139., 139.])
# Valid loss:  1.176795153888819
# -------------------------------
# Epochs:  tensor([140., 140., 144., 140., 140., 140., 140.])
# Valid loss:  0.9785358957250633
# -------------------------------
# Epochs:  tensor([141., 141., 145., 141., 141., 141., 141.])
# Valid loss:  0.9751755660230075
# -------------------------------
# Epochs:  tensor([142., 142., 146., 142., 142., 142., 142.])
# Valid loss:  0.9839532276366394
# -------------------------------
# Epochs:  tensor([143., 143., 147., 143., 143., 143., 143.])
# Valid loss:  0.8929356047655755
# -------------------------------
# Epochs:  tensor([144., 144., 148., 144., 144., 144., 144.])
# Valid loss:  0.9262798009790167
# -------------------------------
# Epochs:  tensor([145., 145., 149., 145., 145., 145., 145.])
# Valid loss:  0.9729697200991927
# -------------------------------
# Epochs:  tensor([146., 146., 150., 146., 146., 146., 146.])
# Valid loss:  0.9375534076141919
# -------------------------------
# Epochs:  tensor([147., 147., 151., 147., 147., 147., 147.])
# Valid loss:  1.0609377099793664
# -------------------------------
# Epochs:  tensor([148., 148., 152., 148., 148., 148., 148.])
# Valid loss:  0.967484105173962
# -------------------------------
# Epochs:  tensor([149., 149., 153., 149., 149., 149., 149.])
# Valid loss:  0.9195598451498508
# -------------------------------
# Epochs:  tensor([150., 150., 154., 150., 150., 150., 150.])
# Valid loss:  0.927038239182311
# -------------------------------
# Epochs:  tensor([151., 151., 155., 151., 151., 151., 151.])
# Valid loss:  0.9407348871032856
# -------------------------------
# Epochs:  tensor([152., 152., 156., 152., 152., 152., 152.])
# Valid loss:  0.9624151286111473
# -------------------------------
# Epochs:  tensor([153., 153., 157., 153., 153., 153., 153.])
# Valid loss:  0.9177775009775025
# -------------------------------
# Epochs:  tensor([154., 154., 158., 154., 154., 154., 154.])
# Valid loss:  0.9510129480518841
# -------------------------------
# Epochs:  tensor([155., 155., 159., 155., 155., 155., 155.])
# Valid loss:  0.8887492527374595
# -------------------------------
# Epochs:  tensor([156., 156., 160., 156., 156., 156., 156.])
# Valid loss:  0.9507440792458686
# -------------------------------
# Epochs:  tensor([157., 157., 161., 157., 157., 157., 157.])
# Valid loss:  0.9027436269469415
# -------------------------------
# Epochs:  tensor([158., 158., 162., 158., 158., 158., 158.])
# Valid loss:  0.9608511912406724
# -------------------------------
# Epochs:  tensor([159., 159., 164., 159., 159., 159., 159.])
# Valid loss:  0.9221786408140558
# -------------------------------
# Epochs:  tensor([160., 160., 165., 160., 160., 160., 160.])
# Valid loss:  0.9211659184824734
# -------------------------------
# Epochs:  tensor([161., 161., 166., 161., 161., 161., 161.])
# Valid loss:  0.9744744264695975
# -------------------------------
# Epochs:  tensor([162., 162., 167., 162., 162., 162., 162.])
# Valid loss:  0.9318701899541417
# -------------------------------
# Epochs:  tensor([163., 163., 168., 163., 163., 163., 163.])
# Valid loss:  1.0775742258997756
# -------------------------------
# Epochs:  tensor([164., 164., 169., 164., 164., 164., 164.])
# Valid loss:  0.8946338401584906
# -------------------------------
# Epochs:  tensor([165., 165., 170., 165., 165., 165., 165.])
# Valid loss:  0.8849177070745943
# -------------------------------
# Epochs:  tensor([166., 166., 171., 166., 166., 166., 166.])
# Valid loss:  0.8610501292229571
# -------------------------------
# Epochs:  tensor([167., 167., 172., 167., 167., 167., 167.])
# Valid loss:  0.9138309025294695
# -------------------------------
# Epochs:  tensor([168., 168., 173., 168., 168., 168., 168.])
# Valid loss:  0.9902443924137084
# -------------------------------
# Epochs:  tensor([169., 169., 174., 169., 169., 169., 169.])
# Valid loss:  0.9056860392243303
# -------------------------------
# Epochs:  tensor([170., 170., 175., 170., 170., 170., 170.])
# Valid loss:  0.9611976309343312
# -------------------------------
# Epochs:  tensor([171., 171., 176., 171., 171., 171., 171.])
# Valid loss:  1.0514329375624363
# -------------------------------
# Epochs:  tensor([172., 172., 177., 172., 172., 172., 172.])
# Valid loss:  0.913038664287807
# -------------------------------
# Epochs:  tensor([173., 173., 178., 173., 173., 173., 173.])
# Valid loss:  0.9046303554759159
# -------------------------------
# Epochs:  tensor([174., 174., 179., 174., 174., 174., 174.])
# Valid loss:  0.9247052895021655
# -------------------------------
# Epochs:  tensor([175., 175., 180., 175., 175., 175., 175.])
# Valid loss:  0.863959149342759
# -------------------------------
# Epochs:  tensor([176., 176., 181., 176., 176., 176., 176.])
# Valid loss:  0.9808768928787897
# -------------------------------
# Epochs:  tensor([177., 177., 182., 177., 177., 177., 177.])
# Valid loss:  0.944445203626001
# -------------------------------
# Epochs:  tensor([178., 178., 183., 178., 178., 178., 178.])
# Valid loss:  0.8682360586128871
# -------------------------------
# Epochs:  tensor([179., 179., 184., 179., 179., 179., 179.])
# Valid loss:  1.0018375606961092
# -------------------------------
# Epochs:  tensor([180., 180., 185., 180., 180., 180., 180.])
# Valid loss:  1.0050673607110465
# -------------------------------
# Epochs:  tensor([181., 181., 186., 181., 181., 181., 181.])
# Valid loss:  1.0614337697731395
# -------------------------------
# Epochs:  tensor([182., 182., 187., 182., 182., 182., 182.])
# Valid loss:  0.8790313617244438
# -------------------------------
# Epochs:  tensor([183., 183., 188., 183., 183., 183., 183.])
# Valid loss:  0.8659246605569696
# -------------------------------
# Epochs:  tensor([184., 184., 189., 184., 184., 184., 184.])
# Valid loss:  0.9889473635223335
# -------------------------------
# Epochs:  tensor([185., 185., 190., 185., 185., 185., 185.])
# Valid loss:  0.8613632606590259
# -------------------------------
# Epochs:  tensor([186., 186., 191., 186., 186., 186., 186.])
# Valid loss:  0.9314187394772095
# -------------------------------
# Epochs:  tensor([187., 187., 192., 187., 187., 187., 187.])
# Valid loss:  0.950372218414264
# -------------------------------
# Epochs:  tensor([188., 188., 193., 188., 188., 188., 188.])
# Valid loss:  0.8595123531647079
# -------------------------------
# Epochs:  tensor([189., 189., 194., 189., 189., 189., 189.])
# Valid loss:  0.9599615425066864
# -------------------------------
# Epochs:  tensor([190., 190., 196., 190., 190., 190., 190.])
# Valid loss:  0.9025062609773372
# -------------------------------
# Epochs:  tensor([191., 191., 197., 191., 191., 191., 191.])
# Valid loss:  0.9034048406928675
# -------------------------------
# Epochs:  tensor([192., 192., 198., 192., 192., 192., 192.])
# Valid loss:  0.956979661565082
# -------------------------------
# Epochs:  tensor([193., 193., 199., 193., 193., 193., 193.])
# Valid loss:  0.9249431567173474
# -------------------------------
# Epochs:  tensor([194., 194., 200., 194., 194., 194., 194.])
# Valid loss:  0.9063653625242548
# -------------------------------
# Epochs:  tensor([195., 195., 201., 195., 195., 195., 195.])
# Valid loss:  0.83071722050596
# -------------------------------
# Epochs:  tensor([196., 196., 202., 196., 196., 196., 196.])
# Valid loss:  0.9314257142925948
# -------------------------------
# Epochs:  tensor([197., 197., 203., 197., 197., 197., 197.])
# Valid loss:  0.9877956003749568
# -------------------------------
# Epochs:  tensor([198., 198., 204., 198., 198., 198., 198.])
# Valid loss:  0.8939715839020637
# -------------------------------
# Epochs:  tensor([199., 199., 205., 199., 199., 199., 199.])
# Valid loss:  0.8814724182198501
# -------------------------------
# Epochs:  tensor([200., 200., 206., 200., 200., 200., 200.])
# Valid loss:  0.91186586903377
# -------------------------------
# Epochs:  tensor([201., 201., 207., 201., 201., 201., 201.])
# Valid loss:  0.8663524926299546

# %%
torch.save(model.state_dict(), "minimal_overlap.pt")
torch.save(v_loss_list, "minimal_overlap_v_loss_list.pt")

# %%
t=np.arange(0,len(v_loss_list)+1)*20
plt.figure(figsize=(10, 6))  # 设置图形的大小
ax = plt.subplot() 
v_loss_list.insert(0,17.35)
ax.plot(t,v_loss_list)
ax.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t=np.arange(0,len(v_loss_list)+1)*20
#       2 plt.figure(figsize=(10, 6))  # 设置图形的大小
#       3 ax = plt.subplot()
#
# NameError: name 'v_loss_list' is not defined

# %%
X, Y = np.meshgrid(torch.Tensor(lidar.xs), torch.Tensor(lidar.ys))
xlocs = X[::8, ::8].reshape(-1, 1)
ylocs = Y[::8, ::8].reshape(-1, 1)
xlocs=torch.Tensor(xlocs)
ylocs=torch.Tensor(ylocs)
mesh_inputs = torch.hstack((xlocs, ylocs))
mesh_inputs = mesh_inputs.to(device)
plt.figure(figsize=(10, 6))  # 设置图形的大小
ax = plt.subplot() 
with torch.no_grad():
    mesh_dense = model.forward(mesh_inputs)
# torch.save(mesh_dense, "mesh_dense.pt")
# (fig, ax) = plt.subplots(figsize=(10, 10))
den=torch.load("../centralized/mesh/mesh_dense20.pt",map_location=torch.device('cpu'))

ax.tricontourf(xlocs.squeeze(), ylocs.squeeze(), den.squeeze().cpu())
# mesh_dense[:100]
