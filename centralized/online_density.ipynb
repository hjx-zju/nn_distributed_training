# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import glob
import copy
from models.fourier_nn import FourierNet
from floorplans.lidar.lidar import ClippedLidar2D, Lidar2D, RandomPoseLidarDataset, TrajectoryLidarDataset, OnlineTrajectoryLidarDataset

torch.set_default_tensor_type(torch.DoubleTensor)

# %%
data_dir = "../floorplans/32_data"

# waypoint_dir = os.path.join(data_dir, "tight_paths")
waypoint_dir = os.path.join(data_dir, "minimal_overlap")

img_path = os.path.join(data_dir, "floor_img.png")

# Data parameters
num_beams = 20
beam_samps = 25
beam_length = 0.2
spline_res = 30
samp_distribution_factor = 1.0
collision_samps = 50
fine_samps = 3
num_scans_in_window = 500
lidar = Lidar2D(img_path, num_beams, beam_length, beam_samps, 
    samp_distribution_factor, collision_samps, fine_samps,
    border_width=30)
#lidar = ClippedLidar2D(img_path, num_beams, beam_length, beam_samps,
#    border_width=30)

datasets = []
for name in glob.glob1(waypoint_dir, "*.npy"):
    waypoints = np.load(os.path.join(waypoint_dir, name))
    ds = OnlineTrajectoryLidarDataset(lidar, waypoints, 
        spline_res, num_scans_in_window)
    #ds = RandomPoseLidarDataset(lidar, 6000)
    print()
    print(name, " : ", len(ds), " scan points")
    print(name, " : ", (torch.sum(ds.scans[:,2] == 1.0) / ds.scans.shape[0]).data.item(), "hd point ratio")
    datasets.append(ds)

# Concatenate the entire dataset
#cent_ds = torch.utils.data.ConcatDataset(datasets)
num_validation_scans = 500
valset = RandomPoseLidarDataset(lidar, num_validation_scans)
# Out:
# 1.npy  :  705000  scan points
# 1.npy  :  0.04215035460992908 hd point ratio
#
# 2.npy  :  600000  scan points
# 2.npy  :  0.043221666666666665 hd point ratio
#
# 4.npy  :  735000  scan points
# 4.npy  :  0.04234285714285714 hd point ratio
#
# 7.npy  :  660000  scan points
# 7.npy  :  0.048543939393939396 hd point ratio
#
# 3.npy  :  630000  scan points
# 3.npy  :  0.033765079365079366 hd point ratio
#
# 5.npy  :  720000  scan points
# 5.npy  :  0.026881944444444444 hd point ratio
#
# 6.npy  :  675000  scan points
# 6.npy  :  0.04158666666666667 hd point ratio

# %%
if torch.cuda.is_available(): 
    device = torch.device("cuda")
else: 
    device = torch.device("cpu")

# Setup model and centralized optimizer
model = FourierNet([2, 256, 64, 64, 64, 1], scale=0.05).to(device)
opt = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
#batch_size = 10000


loss = torch.nn.BCELoss()
val_loader = torch.utils.data.DataLoader(valset, batch_size=10000)

N = 7
batch_size = 12500
dloaders = []
diters = []
for i in range(N):
    dl = torch.utils.data.DataLoader(datasets[i], batch_size=batch_size)
    dloaders.append(dl)
    diters.append(iter(dl))

epoch_tracker = torch.zeros(N)
current_epoch = 0
epochs = 4
from torch.optim.lr_scheduler import StepLR

# 创建StepLR实例
scheduler = StepLR(opt, step_size=66, gamma=0.5)
v_loss_list=[]
X, Y = np.meshgrid(torch.Tensor(lidar.xs), torch.Tensor(lidar.ys))
xlocs = X[::8, ::8].reshape(-1, 1)
ylocs = Y[::8, ::8].reshape(-1, 1)
xlocs=torch.Tensor(xlocs)
ylocs=torch.Tensor(ylocs)
mesh_inputs = torch.hstack((xlocs, ylocs))
mesh_inputs = mesh_inputs.to(device)
while current_epoch <= 200:
    locs = []
    dens = []
    for i in range(N):
        try:
            batch = next(diters[i])
        except StopIteration:
            epoch_tracker[i] += 1
            diters[i] = iter(dloaders[i])
            batch = next(diters[i])
        locs.append(batch[0].to(device))
        dens.append(batch[1].to(device))
        
    x = torch.cat(locs, axis=0)
    y = torch.cat(dens, axis=0)
        
    opt.zero_grad()
    pd = model.forward(x).squeeze()
    l = loss(pd, y)
    l.backward()
    opt.step()
    if torch.sum(epoch_tracker > current_epoch) >= N:
        current_epoch += 1
        print("-------------------------------")
        print("Epochs: ", epoch_tracker)
        with torch.no_grad():
            vloss = 0.0
            for batch in val_loader:
                x, y = batch[0].to(device), batch[1].to(device)
                pd = model.forward(x).squeeze()
                vloss += loss(pd, y).data
        scheduler.step()
        v_loss_list.append(vloss.item())
        print("Valid loss: ", vloss.item())
    if current_epoch%20==0:
        with torch.no_grad():
            mesh_dense = model.forward(mesh_inputs)
        torch.save(mesh_dense, "min_mesh/mesh_dense"+str(current_epoch)+".pt")
# torch.save(mesh_dense, "mesh_dense.pt")
# Out:
# -------------------------------
# Epochs:  tensor([1., 1., 1., 1., 1., 1., 1.])
# Valid loss:  4.56562457376008
# -------------------------------
# Epochs:  tensor([2., 2., 2., 2., 2., 2., 2.])
# Valid loss:  4.4535869221548054
# -------------------------------
# Epochs:  tensor([3., 3., 3., 3., 3., 3., 3.])
# Valid loss:  4.397080924964541
# -------------------------------
# Epochs:  tensor([4., 4., 4., 4., 4., 4., 4.])
# Valid loss:  4.311529954457345
# -------------------------------
# Epochs:  tensor([5., 6., 5., 5., 5., 5., 5.])
# Valid loss:  4.146420666585111
# -------------------------------
# Epochs:  tensor([6., 7., 6., 6., 6., 6., 6.])
# Valid loss:  3.9677331109055247
# -------------------------------
# Epochs:  tensor([7., 8., 7., 7., 8., 7., 7.])
# Valid loss:  3.853149338649053
# -------------------------------
# Epochs:  tensor([8., 9., 8., 8., 9., 8., 8.])
# Valid loss:  3.5450328591304423
# -------------------------------
# Epochs:  tensor([ 9., 11.,  9., 10., 10.,  9.,  9.])
# Valid loss:  3.475558117997896
# -------------------------------
# Epochs:  tensor([10., 12., 10., 11., 11., 10., 10.])
# Valid loss:  3.270668525357626
# -------------------------------
# Epochs:  tensor([11., 13., 11., 12., 12., 11., 12.])
# Valid loss:  3.2170914940838653
# -------------------------------
# Epochs:  tensor([12., 14., 12., 13., 13., 12., 13.])
# Valid loss:  3.1240130176039327
# -------------------------------
# Epochs:  tensor([13., 15., 13., 14., 15., 13., 14.])
# Valid loss:  3.009383210986992
# -------------------------------
# Epochs:  tensor([14., 17., 14., 15., 16., 14., 15.])
# Valid loss:  2.946739580927312
# -------------------------------
# Epochs:  tensor([15., 18., 15., 16., 17., 15., 16.])
# Valid loss:  2.7179978881651623
# -------------------------------
# Epochs:  tensor([16., 19., 16., 17., 18., 16., 17.])
# Valid loss:  3.104097027839622
# -------------------------------
# Epochs:  tensor([17., 20., 17., 18., 19., 17., 18.])
# Valid loss:  2.8546156868015222
# -------------------------------
# Epochs:  tensor([18., 22., 18., 20., 20., 18., 19.])
# Valid loss:  2.713328715027017
# -------------------------------
# Epochs:  tensor([19., 23., 19., 21., 21., 19., 20.])
# Valid loss:  2.6761392776973896
# -------------------------------
# Epochs:  tensor([20., 24., 20., 22., 23., 20., 21.])
# Valid loss:  2.563482500460038
# -------------------------------
# Epochs:  tensor([21., 25., 21., 23., 24., 21., 22.])
# Valid loss:  2.5178232323238574
# -------------------------------
# Epochs:  tensor([22., 27., 22., 24., 25., 22., 24.])
# Valid loss:  2.832484261087446
# -------------------------------
# Epochs:  tensor([23., 28., 23., 25., 26., 23., 25.])
# Valid loss:  2.4720356391462484
# -------------------------------
# Epochs:  tensor([24., 29., 24., 26., 27., 24., 26.])
# Valid loss:  2.57775671103337
# -------------------------------
# Epochs:  tensor([25., 30., 25., 27., 28., 25., 27.])
# Valid loss:  2.3442590377580963
# -------------------------------
# Epochs:  tensor([26., 31., 26., 28., 30., 26., 28.])
# Valid loss:  2.55490833662214
# -------------------------------
# Epochs:  tensor([27., 33., 27., 30., 31., 27., 29.])
# Valid loss:  2.436387091388421
# -------------------------------
# Epochs:  tensor([28., 34., 28., 31., 32., 28., 30.])
# Valid loss:  2.314512630464555
# -------------------------------
# Epochs:  tensor([30., 35., 29., 32., 33., 29., 31.])
# Valid loss:  2.273193977626403
# -------------------------------
# Epochs:  tensor([31., 36., 30., 33., 34., 30., 32.])
# Valid loss:  2.315623661731797
# -------------------------------
# Epochs:  tensor([32., 38., 31., 34., 35., 31., 33.])
# Valid loss:  2.396142202392838
# -------------------------------
# Epochs:  tensor([33., 39., 32., 35., 37., 32., 34.])
# Valid loss:  2.289893762403874
# -------------------------------
# Epochs:  tensor([34., 40., 33., 36., 38., 33., 36.])
# Valid loss:  2.321632341217828
# -------------------------------
# Epochs:  tensor([35., 41., 34., 37., 39., 34., 37.])
# Valid loss:  2.325747363374703
# -------------------------------
# Epochs:  tensor([36., 43., 35., 38., 40., 35., 38.])
# Valid loss:  2.2910743459379974
# -------------------------------
# Epochs:  tensor([37., 44., 36., 40., 41., 36., 39.])
# Valid loss:  2.085695290311342
# -------------------------------
# Epochs:  tensor([38., 45., 37., 41., 42., 37., 40.])
# Valid loss:  2.036578954663119
# -------------------------------
# Epochs:  tensor([39., 46., 38., 42., 43., 38., 41.])
# Valid loss:  1.9330178221798398
# -------------------------------
# Epochs:  tensor([40., 47., 39., 43., 45., 39., 42.])
# Valid loss:  2.201900792997075
# -------------------------------
# Epochs:  tensor([41., 49., 40., 44., 46., 40., 43.])
# Valid loss:  2.2156820667197725
# -------------------------------
# Epochs:  tensor([42., 50., 41., 45., 47., 41., 44.])
# Valid loss:  2.0235626336617503
# -------------------------------
# Epochs:  tensor([43., 51., 42., 46., 48., 42., 45.])
# Valid loss:  1.8957405478975353
# -------------------------------
# Epochs:  tensor([44., 52., 43., 47., 49., 43., 46.])
# Valid loss:  1.9663132908483394
# -------------------------------
# Epochs:  tensor([45., 54., 44., 48., 50., 44., 48.])
# Valid loss:  2.2387522229826278
# -------------------------------
# Epochs:  tensor([46., 55., 45., 50., 52., 45., 49.])
# Valid loss:  2.2241368376320785
# -------------------------------
# Epochs:  tensor([47., 56., 46., 51., 53., 46., 50.])
# Valid loss:  2.026443962799404
# -------------------------------
# Epochs:  tensor([48., 57., 47., 52., 54., 47., 51.])
# Valid loss:  1.8123590102490348
# -------------------------------
# Epochs:  tensor([49., 59., 48., 53., 55., 48., 52.])
# Valid loss:  2.1600145433843316
# -------------------------------
# Epochs:  tensor([50., 60., 49., 54., 56., 49., 53.])
# Valid loss:  1.8286358653043426
# -------------------------------
# Epochs:  tensor([51., 61., 50., 55., 57., 50., 54.])
# Valid loss:  1.847115055705046
# -------------------------------
# Epochs:  tensor([52., 62., 51., 56., 59., 51., 55.])
# Valid loss:  1.7230493136973741
# -------------------------------
# Epochs:  tensor([53., 63., 52., 57., 60., 52., 56.])
# Valid loss:  2.2973804991099858
# -------------------------------
# Epochs:  tensor([54., 65., 53., 59., 61., 53., 57.])
# Valid loss:  2.0794381443073178
# -------------------------------
# Epochs:  tensor([55., 66., 54., 60., 62., 54., 59.])
# Valid loss:  1.8969736194250715
# -------------------------------
# Epochs:  tensor([56., 67., 55., 61., 63., 55., 60.])
# Valid loss:  2.040344354294588
# -------------------------------
# Epochs:  tensor([57., 68., 56., 62., 64., 56., 61.])
# Valid loss:  1.8648488693181833
# -------------------------------
# Epochs:  tensor([59., 70., 57., 63., 65., 57., 62.])
# Valid loss:  1.9221365158158534
# -------------------------------
# Epochs:  tensor([60., 71., 58., 64., 67., 59., 63.])
# Valid loss:  3.2080817704549776
# -------------------------------
# Epochs:  tensor([61., 72., 59., 65., 68., 60., 64.])
# Valid loss:  1.7977624672266574
# -------------------------------
# Epochs:  tensor([62., 73., 60., 66., 69., 61., 65.])
# Valid loss:  2.2090461308415392
# -------------------------------
# Epochs:  tensor([63., 74., 61., 67., 70., 62., 66.])
# Valid loss:  1.990403130473478
# -------------------------------
# Epochs:  tensor([64., 76., 62., 69., 71., 63., 67.])
# Valid loss:  1.7437683388962482
# -------------------------------
# Epochs:  tensor([65., 77., 63., 70., 72., 64., 68.])
# Valid loss:  2.100357379506629
# -------------------------------
# Epochs:  tensor([66., 78., 64., 71., 74., 65., 69.])
# Valid loss:  1.700580555348202
# -------------------------------
# Epochs:  tensor([67., 79., 65., 72., 75., 66., 71.])
# Valid loss:  2.4827064311020006
# -------------------------------
# Epochs:  tensor([68., 81., 66., 73., 76., 67., 72.])
# Valid loss:  1.8591157275730876
# -------------------------------
# Epochs:  tensor([69., 82., 67., 74., 77., 68., 73.])
# Valid loss:  1.6445225085250224
# -------------------------------
# Epochs:  tensor([70., 83., 68., 75., 78., 69., 74.])
# Valid loss:  1.580375694164464
# -------------------------------
# Epochs:  tensor([71., 84., 69., 76., 79., 70., 75.])
# Valid loss:  1.8136347092901361
# -------------------------------
# Epochs:  tensor([72., 86., 70., 77., 80., 71., 76.])
# Valid loss:  1.5907690915667563
# -------------------------------
# Epochs:  tensor([73., 87., 71., 79., 82., 72., 77.])
# Valid loss:  1.7945100325379426
# -------------------------------
# Epochs:  tensor([74., 88., 72., 80., 83., 73., 78.])
# Valid loss:  1.612709815562534
# -------------------------------
# Epochs:  tensor([75., 89., 73., 81., 84., 74., 79.])
# Valid loss:  1.5050868771095574
# -------------------------------
# Epochs:  tensor([76., 90., 74., 82., 85., 75., 80.])
# Valid loss:  1.4572324612260448
# -------------------------------
# Epochs:  tensor([77., 92., 75., 83., 86., 76., 81.])
# Valid loss:  1.6594763261786576
# -------------------------------
# Epochs:  tensor([78., 93., 76., 84., 87., 77., 83.])
# Valid loss:  1.5785292462698117
# -------------------------------
# Epochs:  tensor([79., 94., 77., 85., 89., 78., 84.])
# Valid loss:  1.4668519930364532
# -------------------------------
# Epochs:  tensor([80., 95., 78., 86., 90., 79., 85.])
# Valid loss:  1.4952474798524928
# -------------------------------
# Epochs:  tensor([81., 97., 79., 87., 91., 80., 86.])
# Valid loss:  1.4372748397230712
# -------------------------------
# Epochs:  tensor([82., 98., 80., 89., 92., 81., 87.])
# Valid loss:  1.6860443532806222
# -------------------------------
# Epochs:  tensor([83., 99., 81., 90., 93., 82., 88.])
# Valid loss:  1.5730316802642816
# -------------------------------
# Epochs:  tensor([ 84., 100.,  82.,  91.,  94.,  83.,  89.])
# Valid loss:  1.548433077020382
# -------------------------------
# Epochs:  tensor([ 85., 102.,  83.,  92.,  96.,  84.,  90.])
# Valid loss:  1.3868217309401816
# -------------------------------
# Epochs:  tensor([ 86., 103.,  84.,  93.,  97.,  85.,  91.])
# Valid loss:  1.9536507865350088
# -------------------------------
# Epochs:  tensor([ 87., 104.,  85.,  94.,  98.,  86.,  92.])
# Valid loss:  1.4692403620994587
# -------------------------------
# Epochs:  tensor([ 89., 105.,  86.,  95.,  99.,  87.,  93.])
# Valid loss:  1.6212298101393905
# -------------------------------
# Epochs:  tensor([ 90., 106.,  87.,  96., 100.,  88.,  95.])
# Valid loss:  1.4698114894922127
# -------------------------------
# Epochs:  tensor([ 91., 108.,  88.,  97., 101.,  89.,  96.])
# Valid loss:  1.4742471178113694
# -------------------------------
# Epochs:  tensor([ 92., 109.,  89.,  99., 102.,  90.,  97.])
# Valid loss:  1.419858452846147
# -------------------------------
# Epochs:  tensor([ 93., 110.,  90., 100., 104.,  91.,  98.])
# Valid loss:  1.7821883645312993
# -------------------------------
# Epochs:  tensor([ 94., 111.,  91., 101., 105.,  92.,  99.])
# Valid loss:  1.4326572321475974
# -------------------------------
# Epochs:  tensor([ 95., 113.,  92., 102., 106.,  93., 100.])
# Valid loss:  1.3139095405931893
# -------------------------------
# Epochs:  tensor([ 96., 114.,  93., 103., 107.,  94., 101.])
# Valid loss:  1.5067355415155523
# -------------------------------
# Epochs:  tensor([ 97., 115.,  94., 104., 108.,  95., 102.])
# Valid loss:  1.4742865721938698
# -------------------------------
# Epochs:  tensor([ 98., 116.,  95., 105., 109.,  96., 103.])
# Valid loss:  1.2661609350729186
# -------------------------------
# Epochs:  tensor([ 99., 118.,  96., 106., 111.,  97., 104.])
# Valid loss:  1.4471059822901233
# -------------------------------
# Epochs:  tensor([100., 119.,  97., 107., 112.,  98., 105.])
# Valid loss:  1.8613738089052725
# -------------------------------
# Epochs:  tensor([101., 120.,  98., 109., 113.,  99., 107.])
# Valid loss:  1.4409988630743504
# -------------------------------
# Epochs:  tensor([102., 121.,  99., 110., 114., 100., 108.])
# Valid loss:  1.4067388624153305
# -------------------------------
# Epochs:  tensor([103., 122., 100., 111., 115., 101., 109.])
# Valid loss:  1.4112373978486947
# -------------------------------
# Epochs:  tensor([104., 124., 101., 112., 116., 102., 110.])
# Valid loss:  1.3813405920914608
# -------------------------------
# Epochs:  tensor([105., 125., 102., 113., 118., 103., 111.])
# Valid loss:  1.4593751256322678
# -------------------------------
# Epochs:  tensor([106., 126., 103., 114., 119., 104., 112.])
# Valid loss:  1.6707296280591422
# -------------------------------
# Epochs:  tensor([107., 127., 104., 115., 120., 105., 113.])
# Valid loss:  1.343257564968992
# -------------------------------
# Epochs:  tensor([108., 129., 105., 116., 121., 106., 114.])
# Valid loss:  1.2872958577278586
# -------------------------------
# Epochs:  tensor([109., 130., 106., 118., 122., 107., 115.])
# Valid loss:  1.364116572760918
# -------------------------------
# Epochs:  tensor([110., 131., 107., 119., 123., 108., 116.])
# Valid loss:  1.6240729121199096
# -------------------------------
# Epochs:  tensor([111., 132., 108., 120., 124., 109., 118.])
# Valid loss:  1.367339767318788
# -------------------------------
# Epochs:  tensor([112., 133., 109., 121., 126., 110., 119.])
# Valid loss:  1.3233151559238163
# -------------------------------
# Epochs:  tensor([113., 135., 110., 122., 127., 111., 120.])
# Valid loss:  1.4305588850274154
# -------------------------------
# Epochs:  tensor([114., 136., 111., 123., 128., 112., 121.])
# Valid loss:  1.3997435218989702
# -------------------------------
# Epochs:  tensor([115., 137., 112., 124., 129., 113., 122.])
# Valid loss:  1.3521402205822806
# -------------------------------
# Epochs:  tensor([116., 138., 113., 125., 130., 114., 123.])
# Valid loss:  1.4999958995717144
# -------------------------------
# Epochs:  tensor([118., 140., 114., 126., 131., 115., 124.])
# Valid loss:  1.5126397261281588
# -------------------------------
# Epochs:  tensor([119., 141., 115., 128., 133., 116., 125.])
# Valid loss:  1.6430441380841359
# -------------------------------
# Epochs:  tensor([120., 142., 116., 129., 134., 118., 126.])
# Valid loss:  1.244502421370154
# -------------------------------
# Epochs:  tensor([121., 143., 117., 130., 135., 119., 127.])
# Valid loss:  1.4544592989717795
# -------------------------------
# Epochs:  tensor([122., 145., 118., 131., 136., 120., 128.])
# Valid loss:  1.4818245841955435
# -------------------------------
# Epochs:  tensor([123., 146., 119., 132., 137., 121., 130.])
# Valid loss:  1.4202218860957356
# -------------------------------
# Epochs:  tensor([124., 147., 120., 133., 138., 122., 131.])
# Valid loss:  1.2104983092874728
# -------------------------------
# Epochs:  tensor([125., 148., 121., 134., 139., 123., 132.])
# Valid loss:  1.2273882541007735
# -------------------------------
# Epochs:  tensor([126., 149., 122., 135., 141., 124., 133.])
# Valid loss:  1.335599183424493
# -------------------------------
# Epochs:  tensor([127., 151., 123., 136., 142., 125., 134.])
# Valid loss:  1.306650182038302
# -------------------------------
# Epochs:  tensor([128., 152., 124., 138., 143., 126., 135.])
# Valid loss:  1.392629094161291
# -------------------------------
# Epochs:  tensor([129., 153., 125., 139., 144., 127., 136.])
# Valid loss:  1.760516088306742
# -------------------------------
# Epochs:  tensor([130., 154., 126., 140., 145., 128., 137.])
# Valid loss:  1.375029449126708
# -------------------------------
# Epochs:  tensor([131., 156., 127., 141., 146., 129., 138.])
# Valid loss:  1.255259805171117
# -------------------------------
# Epochs:  tensor([132., 157., 128., 142., 148., 130., 139.])
# Valid loss:  1.252705189954009
# -------------------------------
# Epochs:  tensor([133., 158., 129., 143., 149., 131., 140.])
# Valid loss:  1.1801197427722794
# -------------------------------
# Epochs:  tensor([134., 159., 130., 144., 150., 132., 142.])
# Valid loss:  1.1469339522016293
# -------------------------------
# Epochs:  tensor([135., 161., 131., 145., 151., 133., 143.])
# Valid loss:  1.2798048211796524
# -------------------------------
# Epochs:  tensor([136., 162., 132., 146., 152., 134., 144.])
# Valid loss:  1.2902574293496951
# -------------------------------
# Epochs:  tensor([137., 163., 133., 148., 153., 135., 145.])
# Valid loss:  1.1970616680072652
# -------------------------------
# Epochs:  tensor([138., 164., 134., 149., 155., 136., 146.])
# Valid loss:  1.1276871486839166
# -------------------------------
# Epochs:  tensor([139., 165., 135., 150., 156., 137., 147.])
# Valid loss:  1.225390317760455
# -------------------------------
# Epochs:  tensor([140., 167., 136., 151., 157., 138., 148.])
# Valid loss:  1.140657118378392
# -------------------------------
# Epochs:  tensor([141., 168., 137., 152., 158., 139., 149.])
# Valid loss:  1.104348381819163
# -------------------------------
# Epochs:  tensor([142., 169., 138., 153., 159., 140., 150.])
# Valid loss:  1.1352966923880519
# -------------------------------
# Epochs:  tensor([143., 170., 139., 154., 160., 141., 151.])
# Valid loss:  1.1255116579632427
# -------------------------------
# Epochs:  tensor([144., 172., 140., 155., 161., 142., 152.])
# Valid loss:  1.2883230989372112
# -------------------------------
# Epochs:  tensor([145., 173., 141., 156., 163., 143., 154.])
# Valid loss:  1.2759171323142862
# -------------------------------
# Epochs:  tensor([146., 174., 142., 158., 164., 144., 155.])
# Valid loss:  1.1981112821571702
# -------------------------------
# Epochs:  tensor([148., 175., 143., 159., 165., 145., 156.])
# Valid loss:  1.0923412276855204
# -------------------------------
# Epochs:  tensor([149., 177., 144., 160., 166., 146., 157.])
# Valid loss:  1.1510223156641564
# -------------------------------
# Epochs:  tensor([150., 178., 145., 161., 167., 147., 158.])
# Valid loss:  1.1487149751578676
# -------------------------------
# Epochs:  tensor([151., 179., 146., 162., 168., 148., 159.])
# Valid loss:  1.1598315544066207
# -------------------------------
# Epochs:  tensor([152., 180., 147., 163., 170., 149., 160.])
# Valid loss:  1.0957112557360404
# -------------------------------
# Epochs:  tensor([153., 181., 148., 164., 171., 150., 161.])
# Valid loss:  1.2127790793469606
# -------------------------------
# Epochs:  tensor([154., 183., 149., 165., 172., 151., 162.])
# Valid loss:  1.2549485431593226
# -------------------------------
# Epochs:  tensor([155., 184., 150., 166., 173., 152., 163.])
# Valid loss:  1.137612299100357
# -------------------------------
# Epochs:  tensor([156., 185., 151., 168., 174., 153., 164.])
# Valid loss:  1.1266712736596283
# -------------------------------
# Epochs:  tensor([157., 186., 152., 169., 175., 154., 166.])
# Valid loss:  1.132343925502321
# -------------------------------
# Epochs:  tensor([158., 188., 153., 170., 177., 155., 167.])
# Valid loss:  1.111874186607041
# -------------------------------
# Epochs:  tensor([159., 189., 154., 171., 178., 156., 168.])
# Valid loss:  1.3264246001885118
# -------------------------------
# Epochs:  tensor([160., 190., 155., 172., 179., 157., 169.])
# Valid loss:  1.1006844696839062
# -------------------------------
# Epochs:  tensor([161., 191., 156., 173., 180., 158., 170.])
# Valid loss:  1.1664868298950606
# -------------------------------
# Epochs:  tensor([162., 192., 157., 174., 181., 159., 171.])
# Valid loss:  1.1079238507022795
# -------------------------------
# Epochs:  tensor([163., 194., 158., 175., 182., 160., 172.])
# Valid loss:  1.2168280716478732
# -------------------------------
# Epochs:  tensor([164., 195., 159., 177., 183., 161., 173.])
# Valid loss:  1.0377519616537194
# -------------------------------
# Epochs:  tensor([165., 196., 160., 178., 185., 162., 174.])
# Valid loss:  1.096514183579316
# -------------------------------
# Epochs:  tensor([166., 197., 161., 179., 186., 163., 175.])
# Valid loss:  1.1993643152975806
# -------------------------------
# Epochs:  tensor([167., 199., 162., 180., 187., 164., 177.])
# Valid loss:  1.0754085934061144
# -------------------------------
# Epochs:  tensor([168., 200., 163., 181., 188., 165., 178.])
# Valid loss:  1.1772609468086344
# -------------------------------
# Epochs:  tensor([169., 201., 164., 182., 189., 166., 179.])
# Valid loss:  1.3094696864924953
# -------------------------------
# Epochs:  tensor([170., 202., 165., 183., 190., 167., 180.])
# Valid loss:  1.1891691990745539
# -------------------------------
# Epochs:  tensor([171., 204., 166., 184., 192., 168., 181.])
# Valid loss:  1.1044126247895627
# -------------------------------
# Epochs:  tensor([172., 205., 167., 185., 193., 169., 182.])
# Valid loss:  1.1201871740881084
# -------------------------------
# Epochs:  tensor([173., 206., 168., 187., 194., 170., 183.])
# Valid loss:  1.256523175308767
# -------------------------------
# Epochs:  tensor([174., 207., 169., 188., 195., 171., 184.])
# Valid loss:  1.1862632549085916
# -------------------------------
# Epochs:  tensor([175., 208., 170., 189., 196., 172., 185.])
# Valid loss:  1.2239156234150363
# -------------------------------
# Epochs:  tensor([177., 210., 171., 190., 197., 173., 186.])
# Valid loss:  1.1053286599013834
# -------------------------------
# Epochs:  tensor([178., 211., 172., 191., 198., 174., 187.])
# Valid loss:  1.2616170067598411
# -------------------------------
# Epochs:  tensor([179., 212., 173., 192., 200., 175., 189.])
# Valid loss:  1.0547127404630976
# -------------------------------
# Epochs:  tensor([180., 213., 174., 193., 201., 177., 190.])
# Valid loss:  1.094431025587715
# -------------------------------
# Epochs:  tensor([181., 215., 175., 194., 202., 178., 191.])
# Valid loss:  1.104965796009985
# -------------------------------
# Epochs:  tensor([182., 216., 176., 195., 203., 179., 192.])
# Valid loss:  1.1391397747130854
# -------------------------------
# Epochs:  tensor([183., 217., 177., 197., 204., 180., 193.])
# Valid loss:  1.0780572209531092
# -------------------------------
# Epochs:  tensor([184., 218., 178., 198., 205., 181., 194.])
# Valid loss:  1.049540505354961
# -------------------------------
# Epochs:  tensor([185., 220., 179., 199., 207., 182., 195.])
# Valid loss:  1.0110251833336812
# -------------------------------
# Epochs:  tensor([186., 221., 180., 200., 208., 183., 196.])
# Valid loss:  0.9917002916772195
# -------------------------------
# Epochs:  tensor([187., 222., 181., 201., 209., 184., 197.])
# Valid loss:  0.994321441435862
# -------------------------------
# Epochs:  tensor([188., 223., 182., 202., 210., 185., 198.])
# Valid loss:  0.9774789152136605
# -------------------------------
# Epochs:  tensor([189., 224., 183., 203., 211., 186., 199.])
# Valid loss:  1.1077031789603424
# -------------------------------
# Epochs:  tensor([190., 226., 184., 204., 212., 187., 201.])
# Valid loss:  1.082042699432029
# -------------------------------
# Epochs:  tensor([191., 227., 185., 205., 214., 188., 202.])
# Valid loss:  1.0625886962693445
# -------------------------------
# Epochs:  tensor([192., 228., 186., 207., 215., 189., 203.])
# Valid loss:  1.0252956186005553
# -------------------------------
# Epochs:  tensor([193., 229., 187., 208., 216., 190., 204.])
# Valid loss:  1.0402735115496466
# -------------------------------
# Epochs:  tensor([194., 231., 188., 209., 217., 191., 205.])
# Valid loss:  1.0695987304709884
# -------------------------------
# Epochs:  tensor([195., 232., 189., 210., 218., 192., 206.])
# Valid loss:  0.9973997520554236
# -------------------------------
# Epochs:  tensor([196., 233., 190., 211., 219., 193., 207.])
# Valid loss:  1.0480874145126706
# -------------------------------
# Epochs:  tensor([197., 234., 191., 212., 220., 194., 208.])
# Valid loss:  0.9850745270187742
# -------------------------------
# Epochs:  tensor([198., 236., 192., 213., 222., 195., 209.])
# Valid loss:  1.0069336762226053
# -------------------------------
# Epochs:  tensor([199., 237., 193., 214., 223., 196., 210.])
# Valid loss:  0.9882180911004393
# -------------------------------
# Epochs:  tensor([200., 238., 194., 215., 224., 197., 211.])
# Valid loss:  1.0126190046849826
# -------------------------------
# Epochs:  tensor([201., 239., 195., 217., 225., 198., 213.])
# Valid loss:  1.0827662263925388
# -------------------------------
# Epochs:  tensor([202., 240., 196., 218., 226., 199., 214.])
# Valid loss:  1.0492605938662973
# -------------------------------
# Epochs:  tensor([203., 242., 197., 219., 227., 200., 215.])
# Valid loss:  1.1076355203168202
# -------------------------------
# Epochs:  tensor([204., 243., 198., 220., 229., 201., 216.])
# Valid loss:  1.005671955905387
# -------------------------------
# Epochs:  tensor([205., 244., 199., 221., 230., 202., 217.])
# Valid loss:  1.026427991808709
# -------------------------------
# Epochs:  tensor([207., 245., 200., 222., 231., 203., 218.])
# Valid loss:  0.9556017672121548
# -------------------------------
# Epochs:  tensor([208., 247., 201., 223., 232., 204., 219.])
# Valid loss:  0.904766862851195

# %%
torch.save(model.state_dict(), "minimal_overlap.pt")
torch.save(v_loss_list, "minimal_overlap_v_loss_list.pt")

# %%
v_loss_list=torch.load("minimal_overlap_v_loss_list.pt")
v_loss_list
# Out:
# [4.9662253882394305,
#  4.854167397386668,
#  4.797851377862349,
#  4.697512438685828,
#  4.505315940797392,
#  4.378802411749629,
#  4.146357018510614,
#  3.9698102216076134,
#  3.8229543913716406,
#  3.7012260681589177,
#  3.5496735711330714,
#  3.365307473049458,
#  3.3552015247412066,
#  3.279105909018779,
#  3.1184086099838026,
#  3.0612033420681284,
#  3.0036486326615472,
#  2.9402729034383506,
#  2.856823945672908,
#  2.6111907738552915,
#  2.593781547730655,
#  2.444268729789816,
#  2.531827062713779,
#  2.898640959777293,
#  2.5114295375993296,
#  2.2269199121916214,
#  2.3439585908966953,
#  2.3551303182559264,
#  2.109261506618552,
#  2.191926409535947,
#  2.137916443032294,
#  2.1279711769947385,
#  2.0671534114689996,
#  2.0937106392709066,
#  2.1313980092614617,
#  2.1202568136879076,
#  2.0773017393816495,
#  1.992641664402144,
#  1.7971611108502583,
#  2.007263404722074,
#  1.8169903455452803,
#  1.8837952400137112,
#  2.1772009014614935,
#  2.028141401677709,
#  1.9798575702624437,
#  1.8291329312126154,
#  1.9391584245222027,
#  1.7463232159820505,
#  1.9126115575071034,
#  1.6383699391548454,
#  1.8050681448983275,
#  2.11526028174002,
#  1.9949461129644128,
#  1.8029767449239458,
#  1.8158402068444428,
#  1.626613290402728,
#  2.0226658944822105,
#  1.8778468506996386,
#  1.8768402448258477,
#  1.657896676687649,
#  1.770921270750009,
#  1.599928156423217,
#  1.680655465396736,
#  1.7510808442656594,
#  1.516037124144414,
#  1.7515701795181713,
#  1.630137881901432,
#  1.528133276725899,
#  1.6111164302228862,
#  1.3563364766975958,
#  1.4620295305459217,
#  1.522352506169225,
#  1.4039196778873138,
#  1.4993253320717874,
#  1.3434452479560535,
#  1.3607013032721722,
#  1.4228352449275898,
#  1.3545852456373444,
#  1.3383336338559622,
#  1.3759009481466369,
#  1.4955332777180896,
#  1.4008971468348914,
#  1.3315524601521143,
#  1.233645309971646,
#  1.3475769998022327,
#  1.6538761077542226,
#  1.4753031849777194,
#  1.2852469029660971,
#  1.3424266093937458,
#  1.3635154241592973,
#  1.3648908649057276,
#  1.3766227619914781,
#  1.4422179556798111,
#  1.4033693589578697,
#  1.3583626290362436,
#  1.334734163250295,
#  1.2445163182734973,
#  1.326789369258262,
#  1.568438275253154,
#  1.3617828876953648,
#  1.314580340806373,
#  1.291194107771131,
#  1.3092218498805044,
#  1.2923742394942632,
#  1.4418534791345174,
#  1.416676174067721,
#  1.5362587846247229,
#  1.2863766206321148,
#  1.3273288067648144,
#  1.4868378849052069,
#  1.244077730794573,
#  1.2161338974393832,
#  1.3010556973752596,
#  1.268577587365411,
#  1.1438166380731798,
#  1.307497855631594,
#  1.5784441743949154,
#  1.2262194589772288,
#  1.1307275304552338,
#  1.1278307955779536,
#  1.1491782038513785,
#  1.2639283995126145,
#  1.2090985580435785,
#  1.4763740673796046,
#  1.1636924992886675,
#  1.178522362169246,
#  1.3213759598328685,
#  1.1605669419399476,
#  1.254697506406863,
#  1.2646687976729694,
#  1.3032080517928548,
#  1.3552088740263968,
#  1.1342886315009182,
#  1.0302250100240098,
#  1.0745786721702226,
#  1.0066581343476517,
#  1.0712539241410566,
#  0.9710474347880761,
#  1.1035799059413303,
#  1.0499953304669563,
#  1.0286815287258293,
#  1.177129508188051,
#  1.0736238195770131,
#  1.0388809452403351,
#  1.0715002726666225,
#  1.1723965104271374,
#  1.0181215252228313,
#  0.9911694233704522,
#  1.1210289060498577,
#  1.059708185065947,
#  1.0334121627727486,
#  1.166234962466427,
#  0.9641499308461791,
#  1.052965517535517,
#  1.135460984591131,
#  1.0366152063462124,
#  1.13107868056378,
#  1.0525542115968358,
#  1.0596259776501369,
#  1.019153641275599,
#  0.9646887844571281,
#  0.915966244377902,
#  1.0446937597925814,
#  1.0806327141847498,
#  0.9567161773356273,
#  1.1499729198955373,
#  1.1660559412110663,
#  1.0590207750121814,
#  1.0176238524004995,
#  0.9755389607913489,
#  1.0511093386624029,
#  0.911416659100122,
#  1.1217278427395982,
#  0.9671944824516917,
#  1.0215581380903336,
#  0.9756721328137585,
#  1.2908904470899158,
#  1.016724339223776,
#  0.9734994018004506,
#  0.984816635454951,
#  1.070599879841647,
#  1.0329249359903594,
#  0.8919284105722709,
#  0.9593669506190857,
#  0.9337670123719205,
#  0.9412226761441242,
#  1.1155050198886112,
#  1.0153483525039184,
#  1.1730450472186484,
#  0.919940734723429,
#  0.9580470063491717,
#  0.9362029653724744,
#  0.923085617380244,
#  0.8782527781658622,
#  0.9681372933783841,
#  1.0605604535843032,
#  1.0612095268484518,
#  1.0004733948531521,
#  0.8733437647964775,
#  0.8026535936352412,
#  0.8851928277010153]

# %%
t=np.arange(0,len(v_loss_list)+1)*20
plt.figure(figsize=(10, 6))  # 设置图形的大小
ax = plt.subplot() 
v_loss_list.insert(0,17.35)
ax.plot(t,v_loss_list)
ax.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t=np.arange(0,len(v_loss_list)+1)*20
#       2 plt.figure(figsize=(10, 6))  # 设置图形的大小
#       3 ax = plt.subplot()
#
# NameError: name 'v_loss_list' is not defined

# %%
X, Y = np.meshgrid(torch.Tensor(lidar.xs), torch.Tensor(lidar.ys))
xlocs = X[::8, ::8].reshape(-1, 1)
ylocs = Y[::8, ::8].reshape(-1, 1)
xlocs=torch.Tensor(xlocs)
ylocs=torch.Tensor(ylocs)
mesh_inputs = torch.hstack((xlocs, ylocs))
mesh_inputs = mesh_inputs.to(device)
plt.figure(figsize=(10, 6))  # 设置图形的大小
ax = plt.subplot() 
with torch.no_grad():
    mesh_dense = model.forward(mesh_inputs)
# torch.save(mesh_dense, "mesh_dense.pt")
# (fig, ax) = plt.subplots(figsize=(10, 10))
den=torch.load("../centralized/mesh/mesh_dense20.pt",map_location=torch.device('cpu'))

ax.tricontourf(xlocs.squeeze(), ylocs.squeeze(), den.squeeze().cpu())
# mesh_dense[:100]
